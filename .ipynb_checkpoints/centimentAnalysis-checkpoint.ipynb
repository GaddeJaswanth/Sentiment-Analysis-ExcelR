# %% [markdown]
# #Sentiment Analysis with Python

# %%
#Loading the data to the variable as DataFrame
#importing pandas library
import pandas as pd
#import counter vectorized function from sklearn
from sklearn.feature_extraction.text import CountVectorizer
count=CountVectorizer()
data=pd.read_csv("emails.csv")
data.head()
# Out:
#    Unnamed: 0                  filename  \
# 0           0   arnold-j/_sent_mail/34.
# 1           1  arnold-j/_sent_mail/517.
# 2           2  arnold-j/_sent_mail/743.
# 3           3  arnold-j/_sent_mail/766.
# 4           4  arnold-j/_sent_mail/797.
#
#                                       Message-ID  \
# 0  <15267340.1075857594923.JavaMail.evans@thyme>
# 1  <15539583.1075857652152.JavaMail.evans@thyme>
# 2   <4339799.1075857657711.JavaMail.evans@thyme>
# 3  <25574783.1075857658215.JavaMail.evans@thyme>
# 4  <19506151.1075857658895.JavaMail.evans@thyme>
#
#                                              content    Class
# 0  eat shit\r\n\r\n\r\n\r\n\r\nJohn J Lavorato@ex...  Abusive
# 1                                           fuck you  Abusive
# 2  Gentlemen:\r\nThe following champagne is avail...  Abusive
# 3  sorry i've taken so long...just been trying to...  Abusive
# 4  asshole\r\n\r\n\r\n\r\n\r\nJohn J Lavorato@exc...  Abusive

# %%
#finding the positive and negative text in Data
pos=data[data['Class']=="Non Abusive"]
neg=data[data['Class']=="Abusive"]
print("Positive text \n",pos.head()[['content', 'Class']])
print("\nNegative text \n",neg.head()[['content', 'Class']])
# Out:
# Positive text
#                                                  content        Class
# 3410                      Here is our forecast\r\n\r\n   Non Abusive
# 3411  Traveling to have a business meeting takes the...  Non Abusive
# 3412                     test successful.  way to go!!!  Non Abusive
# 3413  Randy,\r\n\r\n Can you send me a schedule of t...  Non Abusive
# 3414                Let's shoot for Tuesday at 11:45.    Non Abusive
#
# Negative text
#                                               content    Class
# 0  eat shit\r\n\r\n\r\n\r\n\r\nJohn J Lavorato@ex...  Abusive
# 1                                           fuck you  Abusive
# 2  Gentlemen:\r\nThe following champagne is avail...  Abusive
# 3  sorry i've taken so long...just been trying to...  Abusive
# 4  asshole\r\n\r\n\r\n\r\n\r\nJohn J Lavorato@exc...  Abusive

# %%
#Plotting the Postive vs Negative in piechart.
#Importing matplotlib library to plot pie chart.
import matplotlib.pyplot as plt
fig=plt.figure(figsize=(5,5))
temp=[pos['Class'].count(),neg['Class'].count()]
plt.pie(temp,labels=["Non Abusive","Abusive"],autopct ='%2.1f%%',shadow = True,startangle = 50,explode=(0, 0.3))
plt.title('Positive vs Negative')
# Out:
# Text(0.5, 1.0, 'Positive vs Negative')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset into a DataFrame

# Printing the index
print("Index:")
print(data.index)

# Printing the sentiment distribution
sentiment_distribution = data['Class'].value_counts()
print("\nSentiment Distribution:")
print(sentiment_distribution)

# Set the backend to TkAgg
#plt.switch_backend('TkAgg')

# Your plotting code here
# For example:
plt.bar(sentiment_distribution.index, sentiment_distribution.values)
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.title('Sentiment Distribution')
# Out:
# Index:
# RangeIndex(start=0, stop=48076, step=1)
#
# Sentiment Distribution:
# Non Abusive    44666
# Abusive         3410
# Name: Class, dtype: int64
# Text(0.5, 1.0, 'Sentiment Distribution')

# %%
#importing re library 
import re
#Defining preprocessing function to process the data
def preprocess(text):
        text=re.sub('<[^>]*>','',text)
        emoji=re.findall('(?::|;|=)(?:-)?(?:\)|\(|D|P)',text)
        text=re.sub('[\W]+',' ',text.lower()) +' '.join(emoji).replace('-','')
        url_pattern = re.compile(r'https?://\S+|www\.\S+')
        text = url_pattern.sub('', text)
        return text

# %%
#Applying the function preprocess on the data
data['content']=data['content'].apply(preprocess)

# %%
#Displaying the dataframe after applying the preprocessing.
data.head()[['content', 'Class']]
# Out:
#                                              content    Class
# 0  eat shit john j lavorato excelr 11 18 2000 01 ...  Abusive
# 1                                           fuck you  Abusive
# 2  gentlemen the following champagne is available...  Abusive
# 3  sorry i ve taken so long just been trying to f...  Abusive
# 4  asshole john j lavorato excelr 12 23 2000 10 5...  Abusive

# %%
#Defining a function called tokenizer which splits the sentence
def tokenizer(text):
        return text.split()
tokenizer("He was joyful as he was working in good environment")
# Out:
# ['He',
#  'was',
#  'joyful',
#  'as',
#  'he',
#  'was',
#  'working',
#  'in',
#  'good',
#  'environment']

# %%
#Importing stemmer function from NLTK library
from nltk.stem.porter import PorterStemmer
porter=PorterStemmer()
#Defining function for Tokenizer porter
def tokenizer_porter(text):
    return [porter.stem(word) for word in text.split()]

# %%
#Importing NLTK library.
import nltk
from nltk.corpus import stopwords
stop=stopwords.words('english')
#Importing Word cloud
from wordcloud import WordCloud

# %%
#getting positive and negative data
positive_data = data[ data['Class'] == 'Non Abusive']
positive_data = positive_data['content']
negative_data = data[data['Class'] == 'Abusive']
negative_data= negative_data['content']

# %%
#Defining the function to plot the data in wordcloud
def plot_wordcloud(data, color = 'white'):
    words = ' '.join(data)
    not_words = ['ect', 'cc', 'http', 'com', 'www']
    clean_word = " ".join([word for word in words.split() if word not in not_words])
    wordcloud = WordCloud(stopwords=stop,background_color=color,width=2500,height=2000).generate(clean_word)
    plt.figure(1,figsize=(10, 7))
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()

# %%
#Printing the positive data in wordcloud
print("Positive words")
plot_wordcloud(positive_data,'white')
# Out:
# Positive words

# %%
#Printing the negative data in wordcloud
print("Negative words")
plot_wordcloud(negative_data,'black')
# Out:
# Negative words

# %%
#importing tfiVectorizer from sklearn for feature extraction.
from sklearn.feature_extraction.text import TfidfVectorizer
tfid=TfidfVectorizer(strip_accents=None,preprocessor=None,lowercase=False,use_idf=True,norm='l2',tokenizer=None,smooth_idf=True)
y=data.Class.values
#scaling the data
x=tfid.fit_transform(data.content)

# %%
#splitting the train and test split using train_test_split function of sklearn
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(x,y,random_state=1,test_size=0.5,shuffle=False)

# %%
#Importing Logisitic RegressionCV from sklearn library
from sklearn.linear_model import LogisticRegressionCV
model=LogisticRegressionCV(cv=6,scoring='accuracy',random_state=0,n_jobs=-1,verbose=3,max_iter=500).fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   6 | elapsed:  1.7min remaining:   52.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:  1.8min finished
# array(['Non Abusive', 'Non Abusive', 'Non Abusive', ..., 'Non Abusive',
#        'Non Abusive', 'Non Abusive'], dtype=object)

# %%
#Importing metrics from sklesrn to calculate accuracy
from sklearn import metrics
# Accuracy of our built model
print("Accuracy of our model:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy of our model: 0.9857309260337799

# %%
data.content
# Out:
# 0        eat shit john j lavorato excelr 11 18 2000 01 ...
# 1                                                 fuck you
# 2        gentlemen the following champagne is available...
# 3        sorry i ve taken so long just been trying to f...
# 4        asshole john j lavorato excelr 12 23 2000 10 5...
#                                ...
# 48071    dear market participants please note the chang...
# 48072    according to my fancy ciphering we made 310 03...
# 48073    business highlights weather group let 01 s giv...
# 48074    welcome to diamonds newsletter issue 2000 12 s...
# 48075     forwarded by tamara jae black hou ect on 12 0...
# Name: content, Length: 48076, dtype: object

# %%
import pickle

LR_pkl_filename = 'LogisticRegression.pkl'
LR_Model_pkl = open(LR_pkl_filename, 'wb')
pickle.dump(model, LR_Model_pkl)

TF_pkl_filename = 'TfidfVectorizer.pkl'
TF_Model_pkl = open(TF_pkl_filename, 'wb')
pickle.dump(tfid, TF_Model_pkl)
LR_Model_pkl.close()
TF_Model_pkl.close()
